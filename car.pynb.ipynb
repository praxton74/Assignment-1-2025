# %%
import numpy as np

# %%
import pandas as pd

# %%
car=pd.read_csv('car.csv')

# %%
car.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
car[car['year']>2017]
# Out:
#                                     name  year  selling_price  km_driven  \
# 12       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 25       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 27           Hyundai Venue SX Opt Diesel  2019        1195000       5000
# 31     Maruti Vitara Brezza ZDi Plus AMT  2018         975000       4500
# 33                       Honda City V MT  2018         930000      14500
# ...                                  ...   ...            ...        ...
# 4304  Audi Q5 3.0 TDI Quattro Technology  2018        3899000      22000
# 4307                    Mahindra Xylo H4  2019         599000      15000
# 4308                 Maruti Alto 800 LXI  2018         200000      35000
# 4312               Maruti Ertiga 1.5 VDI  2019        1000000      15000
# 4313  Ford Endeavour 2.2 Titanium AT 4X2  2019        2800000      10000
#
#         fuel seller_type transmission        owner
# 12    Petrol      Dealer    Automatic  First Owner
# 25    Petrol      Dealer    Automatic  First Owner
# 27    Diesel      Dealer       Manual  First Owner
# 31    Diesel      Dealer    Automatic  First Owner
# 33    Petrol      Dealer       Manual  First Owner
# ...      ...         ...          ...          ...
# 4304  Diesel      Dealer    Automatic  First Owner
# 4307  Diesel  Individual       Manual  Third Owner
# 4308  Petrol  Individual       Manual  First Owner
# 4312  Diesel  Individual       Manual  First Owner
# 4313  Diesel  Individual    Automatic  First Owner
#
# [609 rows x 8 columns]

# %%
car[car['selling_price']>700000]
# Out:
#                                     name  year  selling_price  km_driven  \
# 8               Hyundai Creta 1.6 VTVT S  2015         850000      25000
# 12       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 21              Hyundai Creta 1.6 VTVT S  2015         850000      25000
# 25       Toyota Corolla Altis 1.8 VL CVT  2018        1650000      25000
# 27           Hyundai Venue SX Opt Diesel  2019        1195000       5000
# ...                                  ...   ...            ...        ...
# 4311             Toyota Camry Hybrid 2.5  2017        1900000      20118
# 4312               Maruti Ertiga 1.5 VDI  2019        1000000      15000
# 4313  Ford Endeavour 2.2 Titanium AT 4X2  2019        2800000      10000
# 4332        Mahindra Scorpio S2 7 Seater  2015         750000     120000
# 4338    Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
#
#         fuel seller_type transmission        owner
# 8     Petrol  Individual       Manual  First Owner
# 12    Petrol      Dealer    Automatic  First Owner
# 21    Petrol  Individual       Manual  First Owner
# 25    Petrol      Dealer    Automatic  First Owner
# 27    Diesel      Dealer       Manual  First Owner
# ...      ...         ...          ...          ...
# 4311  Petrol      Dealer    Automatic  First Owner
# 4312  Diesel  Individual       Manual  First Owner
# 4313  Diesel  Individual    Automatic  First Owner
# 4332  Diesel  Individual       Manual  First Owner
# 4338  Diesel  Individual       Manual  First Owner
#
# [770 rows x 8 columns]

# %%
car[car['selling_price']<1650000]
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4197 rows x 8 columns]

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='selling_price',y='km_driven',data=car,hue='owner')
plt.show()

# %%
car.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
y=car[['year']]

# %%
x=car[['selling_price']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#       selling_price
# 1090         835000
# 3015         516000
# 191         1500000
# 3449         270000
# 1686         229999

# %%
x_test.head()
# Out:
#       selling_price
# 3413         500000
# 2574        2800000
# 3403         260000
# 3108         250000
# 1463         165000

# %%
y_train.head()
# Out:
#       year
# 1090  2017
# 3015  2015
# 191   2013
# 3449  2013
# 1686  2011

# %%
y_test.head()
# Out:
#       year
# 3413  2019
# 2574  2013
# 3403  2015
# 3108  2016
# 1463  2013

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#       year
# 3413  2019
# 2574  2013
# 3403  2015
# 3108  2016
# 1463  2013

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#       year
# 3413  2019
# 2574  2013
# 3403  2015
# 3108  2016
# 1463  2013

# %%
y_pred[0:5]
# Out:
# array([[2013.12343451],
#        [2019.62090428],
#        [2012.44543767],
#        [2012.4171878 ],
#        [2012.17706392]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 15.420696704675516

# %%
# model-2

# %%
y=car[['year']]

# %%
x=car[['selling_price','km_driven','fuel','seller_type']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 13.906427185817044
