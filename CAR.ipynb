# %%
import numpy as np

# %%
import pandas as pd

# %%
car=pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')

# %%
car.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
four_lakh_plus=car['selling_price']>1500000

# %%
car[car['selling_price']>8000000]
# Out:
#                                                    name  year  selling_price  \
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
#       km_driven    fuel seller_type transmission        owner
# 89         6500  Diesel      Dealer    Automatic  First Owner
# 3872      13000  Petrol      Dealer    Automatic  First Owner

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='selling_price',y='year',data=car,hue='fuel')
plt.show()

# %%
car[car['year']==2020]
# Out:
#                                               name  year  selling_price  \
# 158                             Maruti Wagon R LXI  2020         240000
# 176                        Maruti Alto K10 LXI CNG  2020         282000
# 289                 Mahindra XUV500 W11 Option AWD  2020        1400000
# 694              Hyundai Grand i10 Nios Magna CRDi  2020         700000
# 963                              Audi A5 Sportback  2020        4700000
# 1002                   Hyundai Creta 1.4 EX Diesel  2020        1050000
# 1195                            Maruti Baleno Zeta  2020         700000
# 1291                           Maruti Alto 800 VXI  2020         350000
# 1324                              Maruti Swift VXI  2020         619000
# 1409         Volkswagen Polo 1.0 TSI Highline Plus  2020         802000
# 1428                 Hyundai Grand i10 Nios Sportz  2020         600000
# 1432              Hyundai Grand i10 Nios AMT Magna  2020         640000
# 1516                Mahindra XUV500 W11 Option AWD  2020        1400000
# 1575                              Renault KWID RXL  2020         300000
# 1595                            Maruti Alto K10 LX  2020         250000
# 1689             Hyundai Elite i20 Magna Plus BSIV  2020         545000
# 1714                Ford Freestyle Titanium Diesel  2020         784000
# 1715                            Ford Figo Titanium  2020         635000
# 1716             Ford Ecosport 1.5 Diesel Titanium  2020        1000000
# 1774                     Ford Aspire Titanium BSIV  2020         828999
# 1775  Ford EcoSport 1.5 Ti VCT MT Titanium BE BSIV  2020        1119000
# 1776                            Ford Figo Titanium  2020         746000
# 1777                Ford Ecosport 1.5 Petrol Trend  2020        1030000
# 1778     Ford EcoSport 1.5 TDCi Titanium Plus BSIV  2020        1334000
# 1779                       Ford Freestyle Titanium  2020         811999
# 1780          Ford Ecosport Thunder Edition Diesel  2020        1331000
# 1781                  Ford Freestyle Titanium Plus  2020         852000
# 1963                   Hyundai Venue SX Opt Diesel  2020        1000000
# 2016                                Tata Altroz XZ  2020         830000
# 2129                       Honda BR-V i-VTEC VX MT  2020        1250000
# 2137                         Maruti Ertiga 1.5 VDI  2020         550000
# 2154                   Ford Ecosport Sports Petrol  2020        1100000
# 2211                   Hyundai Creta 1.4 EX Diesel  2020        1050000
# 2360          Renault KWID Climber 1.0 MT Opt BSIV  2020         541000
# 2476                                Tata Altroz XE  2020         500000
# 2481                    Hyundai Santro Sportz BSIV  2020         520000
# 2558                         Maruti Swift ZXI Plus  2020         550000
# 2699                      Mahindra Scorpio S5 BSIV  2020        1200000
# 3024                           Maruti Alto 800 LXI  2020         347000
# 3050                           Maruti Alto 800 LXI  2020         310000
# 3112              Maruti Eeco CNG 5 Seater AC BSIV  2020         495000
# 3268                              Maruti Swift VXI  2020         619000
# 3422                           Maruti Alto 800 VXI  2020         210000
# 3431               Hyundai Venue SX Opt Turbo BSIV  2020        1050000
# 3486        Hyundai Grand i10 1.2 Kappa Magna BSIV  2020         545000
# 3933            Ford Figo Aspire 1.5 TDCi Titanium  2020         530000
# 4105                               Tata Harrier XE  2020         426000
# 4278                     Honda Amaze S Petrol BSIV  2020         614000
#
#       km_driven    fuel seller_type transmission                 owner
# 158      120000  Petrol  Individual       Manual           First Owner
# 176       40000     CNG  Individual       Manual           First Owner
# 289       25000  Diesel      Dealer       Manual           First Owner
# 694        1400  Diesel  Individual       Manual           First Owner
# 963        1500  Diesel  Individual    Automatic           First Owner
# 1002      10000  Diesel  Individual       Manual           First Owner
# 1195       1100  Petrol  Individual       Manual           First Owner
# 1291       1000  Petrol  Individual       Manual           First Owner
# 1324       1500  Petrol  Individual       Manual           First Owner
# 1409       5000  Petrol  Individual       Manual           First Owner
# 1428       5000  Petrol  Individual       Manual           First Owner
# 1432       4000  Petrol  Individual    Automatic           First Owner
# 1516      25000  Diesel      Dealer       Manual           First Owner
# 1575      20000  Petrol  Individual       Manual           First Owner
# 1595       1100  Petrol  Individual       Manual  Fourth & Above Owner
# 1689       7300  Petrol  Individual       Manual           First Owner
# 1714        101  Diesel      Dealer       Manual        Test Drive Car
# 1715        101  Petrol      Dealer       Manual        Test Drive Car
# 1716        101  Diesel      Dealer       Manual        Test Drive Car
# 1774       1010  Petrol      Dealer       Manual        Test Drive Car
# 1775       1010  Petrol      Dealer       Manual        Test Drive Car
# 1776       1111  Petrol      Dealer       Manual        Test Drive Car
# 1777       1010  Petrol      Dealer       Manual        Test Drive Car
# 1778       1010  Diesel      Dealer       Manual        Test Drive Car
# 1779       1010  Petrol      Dealer       Manual        Test Drive Car
# 1780       1010  Diesel      Dealer       Manual        Test Drive Car
# 1781       1010  Petrol      Dealer       Manual        Test Drive Car
# 1963       5000  Diesel  Individual       Manual           First Owner
# 2016      10000  Petrol  Individual       Manual           First Owner
# 2129       1100  Petrol      Dealer       Manual           First Owner
# 2137      90000  Diesel  Individual       Manual           First Owner
# 2154       1000  Petrol  Individual       Manual           First Owner
# 2211      10000  Diesel  Individual       Manual           First Owner
# 2360       1000  Petrol      Dealer       Manual        Test Drive Car
# 2476       5000  Petrol  Individual       Manual           First Owner
# 2481       5000  Petrol  Individual       Manual           First Owner
# 2558       5000  Petrol  Individual       Manual           First Owner
# 2699      11000  Diesel  Individual       Manual           First Owner
# 3024       5000  Petrol  Individual       Manual           First Owner
# 3050       1700  Petrol  Individual       Manual           First Owner
# 3112       7000     CNG  Individual       Manual           First Owner
# 3268       1500  Petrol  Individual       Manual           First Owner
# 3422      40000  Petrol  Individual       Manual           First Owner
# 3431       1100  Petrol  Individual       Manual           First Owner
# 3486       5000  Petrol  Individual       Manual           First Owner
# 3933      45000  Diesel      Dealer       Manual           First Owner
# 4105       1000  Diesel  Individual       Manual           First Owner
# 4278       1000  Petrol  Individual       Manual           First Owner

# %%
y=car[['year']]

# %%
x=car[['selling_price']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
 x_test.head()
# Out:
#       selling_price
# 3963         390000
# 606          385000
# 3277         270000
# 2151         550000
# 1765         280000

# %%
x_train.head()
# Out:
#       selling_price
# 2135         150000
# 1787         190000
# 697          150000
# 3194         525000
# 1541         346000

# %%
x_test.head()
# Out:
#       selling_price
# 3963         390000
# 606          385000
# 3277         270000
# 2151         550000
# 1765         280000

# %%
x_train.head()
# Out:
#       selling_price
# 2135         150000
# 1787         190000
# 697          150000
# 3194         525000
# 1541         346000

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred[0:4]
# Out:
# array([[2012.76390734],
#        [2012.74888226],
#        [2012.40330533],
#        [2013.24471002]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 14.614890214861383
