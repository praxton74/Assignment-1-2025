# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitaanyaaaa/Assignment-1-2025/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
 car=pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')

# %%
car.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission  owner
# 0  Individual       Manual      1
# 1  Individual       Manual      1
# 2  Individual       Manual      1
# 3  Individual       Manual      1
# 4  Individual       Manual      2

# %%
car[car['selling_price'] >135000 ]
# Out:
#                                               name  year  selling_price  \
# 2                             Hyundai Verna 1.6 SX  2012         600000
# 3                           Datsun RediGO T Option  2017         250000
# 4                            Honda Amaze VX i-DTEC  2014         450000
# 5                             Maruti Alto LX BSIII  2007         140000
# 6                        Hyundai Xcent 1.2 Kappa S  2016         550000
# ...                                            ...   ...            ...
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012         600000
# 4335           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999
# 4336                    Hyundai i20 Magna 1.4 CRDi  2014         409999
# 4338              Hyundai Creta 1.6 CRDi SX Option  2016         865000
# 4339                              Renault KWID RXT  2016         225000
#
#       km_driven    fuel seller_type transmission  owner
# ...

# %%
car[car['km_driven'] >50000 ]
# Out:
#                                               name  year  selling_price  \
# 0                                    Maruti 800 AC  2007          60000
# 2                             Hyundai Verna 1.6 SX  2012         600000
# 4                            Honda Amaze VX i-DTEC  2014         450000
# 5                             Maruti Alto LX BSIII  2007         140000
# 7                         Tata Indigo Grand Petrol  2014         240000
# ...                                            ...   ...            ...
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012         600000
# 4335           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999
# 4336                    Hyundai i20 Magna 1.4 CRDi  2014         409999
# 4337                           Maruti 800 AC BSIII  2009         110000
# 4338              Hyundai Creta 1.6 CRDi SX Option  2016         865000
#
#       km_driven    fuel seller_type transmission  owner
# ...

# %%
sns.scatterplot(x='selling_price',y='km_driven',data=car,hue="fuel" )
plt.show ()

# %%
x=car[['year']]

# %%
y=car[['km_driven']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#       year
# 986   2007
# 810   2014
# 2661  2006
# 1433  2006
# 2851  2017

# %%
y_test.head()
# Out:
#       km_driven
# 4124      40000
# 196      150000
# 1208      70000
# 3378      76600
# 3008      67000

# %%
x_train.head()
# Out:
#       year
# 986   2007
# 810   2014
# 2661  2006
# 1433  2006
# 2851  2017

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_train )

# %%
y_pred[0:3]
# Out:
# array([[94444.72249803],
#        [61545.13842596],
#        [99144.66307976]])

# %%
mean_squared_error(y_train,y_pred)
# Out:
# 1747453249.440573

# %%
y=car[['km_driven']]

# %%
x=car[['year','selling_price']]

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_train )

# %%
mean_absolute_error(y_train,y_pred)
# Out:
# 28987.818892503812

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([9209253.20993974])

# %%
model.coef_
# Out:
# array([[-4.54133846e+03, -1.80676598e-03]])

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.metrics import mean_squared_error

# %%
y_train.head()
# Out:
#       km_driven
# 982       66000
# 1649      29000
# 3749     120000
# 3695      70000
# 4075      14000

# %%
from sklearn.linear_model import LinearRegression

# %%
y_train.head()
# Out:
#       km_driven
# 982       66000
# 1649      29000
# 3749     120000
# 3695      70000
# 4075      14000

# %%
from matplotlib import pyplot as plt

# %%
import seaborn  as sns
